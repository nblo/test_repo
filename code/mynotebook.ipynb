# %%
import pandas as pd 
import numpy as np

df = pd.DataFrame({"col_1": np.random.randint(10), "col_2": np.random.random(size=10)})

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df["col_3"] = df["col_1"] + df["col_2"]

# %%
df.to_csv("test.csv")

# %%
df.head()
# Out:
#    col_1     col_2     col_3
# 0      3  0.305102  3.305102
# 1      3  0.466567  3.466567
# 2      3  0.517144  3.517144
# 3      3  0.854249  3.854249
# 4      3  0.619292  3.619292

# %%
df.describe()
# Out:
#        col_1      col_2      col_3
# count   10.0  10.000000  10.000000
# mean     3.0   0.529256   3.529256
# std      0.0   0.276442   0.276442
# min      3.0   0.034602   3.034602
# 25%      3.0   0.367617   3.367617
# 50%      3.0   0.503700   3.503700
# 75%      3.0   0.664843   3.664843
# max      3.0   0.990687   3.990687

# %%
X = df[["col_1", "col_2"]]

y = df["col_3"]
